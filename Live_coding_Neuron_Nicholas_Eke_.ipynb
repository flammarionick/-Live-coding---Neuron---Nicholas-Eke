# %% [markdown]
# <a href="https://colab.research.google.com/github/flammarionick/-Live-coding---Neuron---Nicholas-Eke/blob/main/Live_coding_Neuron_Nicholas_Eke_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a class Neuron that defines a single neuron performing binary classification:
#
# class constructor: def __init__(self, nx):
# nx is the number of input features to the neuron
# If nx is not an integer, raise a TypeError with the exception: nx must be an integer
# If nx is less than 1, raise a ValueError with the exception: nx must be a positive integer
# All exceptions should be raised in the order listed above
# Public instance attributes:
# W: The weights vector for the neuron. Upon instantiation, it should be initialized using a random normal distribution.
# b: The bias for the neuron. Upon instantiation, it should be initialized to 0.
# A: The activated output of the neuron (prediction). Upon instantiation, it should be initialized to 0.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')

data.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#data.info()
new_data = pd.get_dummies(data)
new_data.head(5)
# Out:
#    #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0  1    318  45      49       49       65       65     45           1
# 1  2    405  60      62       63       80       80     60           1
# 2  3    525  80      82       83      100      100     80           1
# 3  3    625  80     100      123      122      120     80           1
# 4  4    309  39      52       43       60       50     65           1
#
#    Legendary  ...  Type 2_Ghost  Type 2_Grass  Type 2_Ground  Type 2_Ice  \
# 0      False  ...         False         False          False       False
# 1      False  ...         False         False          False       False
# 2      False  ...         False         False          False       False
# 3      False  ...         False         False          False       False
# 4      False  ...         False         False          False       False
#
#    Type 2_Normal  Type 2_Poison  Type 2_Psychic  Type 2_Rock  Type 2_Steel  \
# ...

# %%
input = np.array(new_data.drop(['Legendary'], axis = 1))
print(input)
# Out:
# [[1 318 45 ... False False False]
#  [2 405 60 ... False False False]
#  [3 525 80 ... False False False]
#  ...
#  [720 600 80 ... False False False]
#  [720 680 80 ... False False False]
#  [721 600 80 ... False False True]]

# %%
print(input.shape)
# Out:
# (800, 845)

# %%
nx = input.shape[1]

# %%
class constructor:
    def __init__(self, nx):
        # Check if nx is an integer
        if not isinstance(nx, int):
            raise TypeError("nx must be an integer")

        # Check if nx is a positive integer
        if nx < 1:
            raise ValueError("nx must be a positive integer")

        # Initialize weights with a random normal distribution and bias as 0
        self.W = np.random.randn(1, nx)  # Weight vector, shape (1, nx)
        self.b = 0  # Bias initialized to 0
        self.A = 0  # Activated output initialized to 0

# %%
# Initialize a Neuron instance with 845 input features
neuron = constructor(nx=845)

# Print the weights, bias, and activation output
print("Weights: ", neuron.W)
print("Bias: ", neuron.b)
print("Activated Output: ", neuron.A)
# Out:
# Weights:  [[ 1.55318950e+00  8.84485186e-01 -4.15457834e-01 -5.83193033e-01
#    7.21564248e-01 -4.62887103e-01 -3.09416780e-01  3.19450913e-01
#    9.54130892e-01  2.14242791e+00  6.91558387e-01 -2.93862665e-02
#   -5.58791559e-02  8.29682061e-02 -3.63328732e-02 -9.06420663e-01
#    6.58537859e-01  4.92455622e-01  3.71002204e-01  7.73634503e-01
#    2.13811399e+00  5.45012947e-01 -4.80330887e-01 -1.34931468e+00
#   -1.06021917e+00 -1.17643271e+00  4.80695552e-01 -1.60908973e+00
#   -7.63616799e-01  7.96667141e-01  2.57362793e-02  4.55540398e-01
#    1.91515139e+00 -2.05794041e+00 -7.43428044e-03  5.77866975e-01
#   -1.27519950e+00  7.69724317e-01  1.45709224e-02 -1.58924602e-01
#   -4.99516620e-01  1.02950359e+00  3.61677823e-02 -2.52285479e-01
#   -1.03640404e+00  4.46371796e-01  1.24230809e+00  3.15657511e-01
#   -3.35497750e-01  1.12418529e-01 -1.23153437e+00 -6.92478490e-01
#   -9.74141492e-01  5.94889436e-02 -1.11293986e+00  9.75462344e-01
# ...

# %%
import pandas as pd

# Load the Pokémon dataset
data = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')

# Display the first 5 rows of the dataset
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Convert categorical variables to dummy variables
new_data = pd.get_dummies(data)

# Display the first 5 rows after preprocessing
new_data.head(5)
# Out:
#    #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0  1    318  45      49       49       65       65     45           1
# 1  2    405  60      62       63       80       80     60           1
# 2  3    525  80      82       83      100      100     80           1
# 3  3    625  80     100      123      122      120     80           1
# 4  4    309  39      52       43       60       50     65           1
#
#    Legendary  ...  Type 2_Ghost  Type 2_Grass  Type 2_Ground  Type 2_Ice  \
# 0      False  ...         False         False          False       False
# 1      False  ...         False         False          False       False
# 2      False  ...         False         False          False       False
# 3      False  ...         False         False          False       False
# 4      False  ...         False         False          False       False
#
#    Type 2_Normal  Type 2_Poison  Type 2_Psychic  Type 2_Rock  Type 2_Steel  \
# ...

# %%
# Extract the input features (all columns except 'Legendary')
input_features = np.array(new_data.drop(['Legendary'], axis=1))

# Display the shape of the input features
print(input_features.shape)  # Expected to be (800, 845)
# Out:
# (800, 845)

# %%
# Get the number of input features
nx = input_features.shape[1]

# %%
# Initialize the Neuron with nx input features
neuron = constructor(nx)

# Print the Neuron's weights, bias, and activation output
print("Weights: ", neuron.W)
print("Bias: ", neuron.b)
print("Activated Output: ", neuron.A)
# Out:
# Weights:  [[-5.65024001e-01 -3.71921149e-01 -7.67715442e-01 -2.01269826e+00
#    8.13162020e-01 -6.59335580e-01 -2.39655376e-01 -3.34531045e-01
#   -2.76543611e-01 -1.69998404e+00 -4.33264911e-01  1.53613340e-01
#   -1.82108604e-01 -7.12100062e-01  2.19923839e+00  5.07539900e-01
#   -2.59823994e-01 -2.05838134e-01 -7.26987689e-01 -1.64895350e-01
#   -1.16794232e+00 -2.86914810e-01 -5.81493205e-01  1.76723232e-01
#    8.18115357e-01 -1.21994989e+00  8.70297685e-01  9.37225853e-01
#    1.94091998e+00  1.33397361e+00 -8.54300025e-01 -7.44027493e-01
#    5.72757482e-01 -1.35382655e+00 -8.90061523e-01  9.99975326e-01
#   -1.31181835e+00  2.45136877e+00 -2.99069155e-01 -1.60416571e-01
#    3.67295534e-01 -1.15430851e+00  3.92168553e-01  3.45649554e-01
#   -1.88543084e-01  2.32937753e-01  1.63277641e-02 -2.39110562e-01
#    9.33670873e-01  4.71327795e-02 -6.90608071e-01  3.99263412e-01
#    1.24614439e-01  1.42155469e-01  1.00207412e+00 -1.09553373e+00
# ...
